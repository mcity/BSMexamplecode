# %% [markdown]
# # Find Nearest Road Segment

# %%
import geopandas as gp
import pandas as pd
import os
import random
from shapely.geometry import Point, LineString
from scipy.signal import medfilt
from more_itertools import unique_everseen
import folium

pd.options.display.max_rows = 16

# %% [markdown]
# ### Choose file to analyze

# %%
tripstart = 41200
filenum = 2
filename = 'TripStart_{0}_p{1:0>3}.csv'.format(tripstart,filenum)

# %% [markdown]
# ### Read in road segment shapefile and extract spatial index

# %% [markdown]
# Shapefile for the Michigan road network can be downloaded from the **State of Michigan GIS Open Data** at http://gis-michigan.opendata.arcgis.com/. You can also get it in KML or GeoJSON.

# %%
# %%time
roads = gp.read_file('MIroads.shp')
sidx = roads.sindex
# Out:
# Wall time: 2min 32s

# %% [markdown]
# ### Read in BSM file

# %% [markdown]
# We round the lat/lon coordinates to 4 decimal places (~11m resolution) and eliminate duplicates. We will merge back the road names with the original dataframe to avoid looking up similar gps coordinates for the same road.

# %%
columns = 'RxDevice,FileId,TxDevice,Gentime,TxRandom,MsgCount,DSecond,Latitude,Longitude,Elevation,Speed,Heading,Ax,Ay,Az,Yawrate,PathCount,RadiusOfCurve,Confidence'
columns = columns.split(',')
trip = pd.read_csv(filename, header=None)
trip.columns = columns
gps4 = trip[[7,8]].round(4)
gps4.columns = ['lat','lon']
trip = pd.concat([trip,gps4], axis=1)
gps4.drop_duplicates(['lat','lon'], inplace=True)
gps4.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Find closest road to gps point

# %%
# %%time
radius = 0.0001
closest_road = []
gps = zip(gps4['lon'],gps4['lat'])
for i, xy in enumerate(gps):
    pt = Point(xy)
    road_id = list(sidx.nearest(pt.buffer(radius).bounds, 1))
    road_dist = [(id,roads.at[id,'geometry'].distance(pt)) for id in road_id]
    road_dist.sort(key=lambda x: x[1])
    closest_road.append(road_dist[0])

nearest_rd = pd.DataFrame(closest_road, columns=['rd1','d1'])
gpsrds = pd.concat([gps4, nearest_rd], axis=1)
# apply median filter to roads to try to remove spurious intersections
gpsrds['rd1'] = medfilt(gpsrds['rd1'],11)
trip_roads = trip.merge(gpsrds, how='left', on=['lat','lon'], suffixes=('','_y'))
trip_roads.drop(['lat','lon'], axis=1, inplace=True)
# merge it back with the original dataframe
trip_roadnames = trip_roads.merge(roads[['RDNAME']], how='left', left_on='rd1', right_index=True)
# Out:
# Wall time: 37.9 s

# %% [markdown]
# ### Print out road names for each trip

# %%
list_trips = []
for (rx,id,tx),df in trip_roadnames.groupby(['RxDevice','FileId','TxDevice']):
    roadlist = df['RDNAME'].tolist()
    print('\nRxDevice={} FileId={} TxDevice={} went through these roads: '.format(rx,id,tx) )
    print(list(unique_everseen(df['RDNAME'].tolist())))
    # grab every 20th data point for the web map
    data = df.iloc[::20,[7,8]]
    list_trips.append(list(zip(data['Latitude'],data['Longitude'])))
# Out:
# RxDevice=22 FileId=22490 TxDevice=22 went through these roads:
# ['Plymouth Rd', 'Green Rd', 'Whisperwood Dr', 'Nixon Rd', 'Dhu Varren Rd', 'N Foxridge Ct', 'Omlesaad Dr']
#
# RxDevice=22 FileId=22491 TxDevice=22 went through these roads:
# ['Green Rd', 'Commonwealth Blvd', 'Plymouth Rd', 'Georgetown Blvd', 'S Huron Pkwy', 'Nixon Rd', 'Traverwood Dr', 'Lake Lila Dr', 'Upland Dr', 'Barton Dr', None, 'Barton Shore Dr', 'Whitmore Lake Rd', 'W M 14', 'E M 14', 'Huron River Dr', 'Miller Rd', 'Dexter Ann Arbor Rd', 'Wagner Rd', 'W I 94', 'I 94 Crossover', 'Baker Rd', 'N Dancer Rd', 'Old US 12', 'Kalmbach Rd', 'Notten Rd', 'Mount Hope Rd', 'Whipple Rd', 'Sargent Rd', 'E I 94', 'Hawkins Rd', 'N Elm Ave', 'Blackman Rd', 'N Sandstone Rd', 'N Dearing Rd', 'W Michigan Ave', 'Eaton Rapids Rd', '29 Mile Rd', '28 Mile Rd', '27 Mile Rd', '24 Mile Rd', '23 Mile Rd', '22 1/2 Mile Rd', 'Partello Rd', '18 1/2 Mile Rd', '17 1/2 Mile Rd', 'Old US 27 N', 'Michigan Ave E', '9 Mile Rd', 'Beadle Lake Rd', '6 1/2 Mile Rd', 'M 66', 'Riverside Dr', 'E Michigan Ave', 'I 94 BL', 'E M L Ave', 'Sprinkle Rd', 'E Kilgore Rd', 'Portage St', 'Lovers Ln']
#
# RxDevice=22 FileId=22492 TxDevice=22 went through these roads:
# ['W I 94', None, 'County Road 657', 'County Road 653', 'I 94 Crossover', '41st St', '46th St', '64th St', 'Friday Rd', 'Park Rd', 'Boyer Rd', 'Carmody Rd', 'Roslin Rd', 'N I 196', 'N Benton Center Rd', 'Territorial Rd', 'E I 94 BL', 'Highland Ave', 'E Britain Ave', 'E Napier Ave', 'Pipestone Rd', 'Nickerson Ave', 'Niles Rd', 'Cleveland Ave', 'W Glenlord Rd', 'Red Arrow Hwy', 'Puetz Rd', 'Grand Mere Rd', 'Cook Power Plant Rd', 'Livingston Rd', 'Wildwood Dr', 'Lake St', 'Harbert Rd', 'Three Oaks Rd', 'W East Rd', 'W Warren Woods Rd', 'Union Pier Rd', 'New Buffalo Weigh Station', 'La Porte Rd', 'Kluver Rd', 'Shedd Rd', 'US 12', 'Grand Beach Rd', 'Michiana Dr']
#
# RxDevice=23 FileId=941131 TxDevice=23 went through these roads:
# ['S Huron Pkwy', 'Asher Rd', 'Lindsay Ct', 'E Huron River Dr', 'Huron River/Huron Pkwy Ramp', 'Huron River Dr', 'Geddes Ave', 'S Observatory St', 'E Medical Center Dr', 'E Hospital Dr', 'Womens Hospital Dr', 'Catherine Pl', 'E Ann St', 'Catherine Rd', 'Simpson Dr', 'N University Ave', 'Hickory Ln', 'Boulder Dr']
#
# RxDevice=23 FileId=941132 TxDevice=23 went through these roads:
# ['Canterbury Rd', 'Platt Rd', 'S Huron Pkwy', 'Service Dr', 'Washtenaw Ave', 'Lindsay Ct', 'E Huron River Dr', 'Huron River/Huron Pkwy Ramp', 'Huron River Dr', 'Geddes Ave', 'S Observatory St', 'E Medical Center Dr', 'E Hospital Dr', 'Womens Hospital Dr', 'Catherine Pl']
#
# RxDevice=23 FileId=941133 TxDevice=23 went through these roads:
# ['Catherine Pl', 'Simpson Dr', 'E Medical Center Dr', 'S Observatory St', 'N University Ave', 'Geddes Ave', 'Wilmot St', 'Washtenaw Ave', 'S University Ave', 'Forest Ct', 'Hill St', 'Cambridge Rd', 'Austin Ave', 'Service Dr', 'E Stadium Blvd', 'Platt Rd', 'Canterbury Rd']
#
# RxDevice=24 FileId=23263 TxDevice=24 went through these roads:
# ['Bluett Rd', 'Burbank Dr', 'Green Rd', 'Commonwealth Blvd', 'Plymouth Rd', 'Baxter Rd', None]
#
# RxDevice=24 FileId=23269 TxDevice=24 went through these roads:
# [None, 'Baxter Rd', 'S Huron Pkwy', 'Plymouth Rd', 'Georgetown Blvd', 'Bluett Rd', 'Lexington Dr', 'Rumsey Dr', 'Yellowstone Dr']
#
# RxDevice=26 FileId=24282 TxDevice=26 went through these roads:
# ['Hillside Dr', 'Hillside Ct', 'N Dixboro Rd', 'Village Green Blvd', 'Geddes Rd', 'Geddes Rd/N US 23 Ramp Cutoff', 'N US 23', 'S US 23 Ramp/Geddes Rd Cutoff', 'Wind Crest Dr', 'WindyCrest Dr', 'Fuller Rd', None, 'Fuller Ct', 'Oakway Rd', 'N Campus Blvd']
#
# RxDevice=27 FileId=24532 TxDevice=27 went through these roads:
# ['Geddes Rd', 'Leforge Rd', 'N Dixboro Rd', 'Geddes Rd/N US 23 Ramp Cutoff', None, 'N US 23', 'Plymouth Rd', 'Earhart Rd', 'Ave Maria Dr']
#
# RxDevice=27 FileId=24533 TxDevice=27 went through these roads:
# ['Earhart Rd', 'Plymouth Rd', 'N Earhart Pl', None, 'N US 23', 'S US 23', 'Geddes Rd', 'S US 23 Ramp/Geddes Rd Cutoff', 'Hunters Creek Dr', 'Abigail Dr', 'Hallie Dr']
#
# RxDevice=27 FileId=24534 TxDevice=27 went through these roads:
# ['Geddes Rd', 'Paddock Way', 'Leforge Rd', 'Superior Rd', 'Riverwood St', 'N Huron River Dr', 'W Huron River Dr', 'N Hewitt Rd', 'Stadium View Dr', 'Washtenaw Ave']
#
# RxDevice=27 FileId=24535 TxDevice=27 went through these roads:
# ['Washtenaw Ave', 'Golfside Dr', 'International Dr', 'W Clark Rd', 'W Huron River Dr', 'N Huron River Dr', 'Superior Rd', 'Riverwood St', 'Geddes Rd', 'Hunters Creek Dr', 'Abigail Dr', 'Hallie Dr']
#
# RxDevice=30 FileId=25395 TxDevice=30 went through these roads:
# ['Jackson Rd', 'S Zeeb Rd', None, 'E I 94', 'E M 14', 'W I 94', 'Dexter Rd', 'Miller Rd', 'N Maple Rd', 'SB N Maple/NB N Maple TURN', 'NB N Maple/SB N Maple TURN', 'W M 14', 'Timber Hill Dr', 'Skyline High School Rd', 'Newport Rd', 'Bird Rd', 'Newport Creek Dr', 'Riverwood Dr', 'Cooley St', 'Sunset Rd', 'Westport Rd', 'Pinetree Dr', 'Morningside Dr', 'Wagner Rd', 'Leroy St', 'Dexter Ann Arbor Rd', 'Elizabeth Rd']
#
# RxDevice=30 FileId=25396 TxDevice=30 went through these roads:
# ['Jackson Rd', 'Park Rd', 'S Burton Rd', 'S Zeeb Rd', None, 'E I 94', 'E M 14', 'W I 94', 'Dexter Rd', 'Miller Rd', 'N Maple Rd', 'SB N Maple/NB N Maple TURN', 'NB N Maple/SB N Maple TURN', 'W M 14', 'Timber Hill Dr', 'Skyline High School Rd']
#
# RxDevice=30 FileId=25397 TxDevice=30 went through these roads:
# ['Skyline High School Rd', 'N Maple Rd', 'Laurentide Dr', 'Newport Rd', 'Lowell Rd', 'Bird Rd', 'Down Up Cir', 'Riverwood Dr', 'W M 14', 'Cooley St', 'Sunset Rd']
#
# RxDevice=30 FileId=25398 TxDevice=30 went through these roads:
# ['Pinetree Dr', 'Morningside Dr', 'Miller Rd', 'Wines Dr', None, 'E M 14', 'Wagner Rd', 'Elizabeth Rd', 'Jackson Rd', 'Parkland Plaza Dr', 'Park Rd', 'Jackson Ave', 'W M 14', 'Kuehnle St', 'Duncan St']
#
# RxDevice=30 FileId=25399 TxDevice=30 went through these roads:
# ['Miller Rd', 'N Maple Rd', 'SB N Maple/NB N Maple TURN', 'NB N Maple/SB N Maple TURN', 'W M 14', 'Skyline High School Rd', 'Timber Hill Dr', None, 'Wagner Rd', 'Leroy St', 'Dexter Ann Arbor Rd', 'Elizabeth Rd', 'E M 14', 'Jackson Rd', 'Auto Mall Dr', 'S Burton Rd', 'Myrtle Ave', 'Park Rd']
#
# RxDevice=30 FileId=25400 TxDevice=30 went through these roads:
# ['Park Rd', 'Myrtle Ave', 'S Burton Rd', 'Jackson Rd', 'S Zeeb Rd', None, 'E I 94', 'E M 14', 'W I 94', 'Dexter Rd', 'Miller Rd', 'N Maple Rd', 'SB N Maple/NB N Maple TURN', 'NB N Maple/SB N Maple TURN', 'W M 14', 'Skyline High School Rd']
#
# RxDevice=30 FileId=25401 TxDevice=30 went through these roads:
# ['Skyline High School Rd', 'N Maple Rd', 'Newport Rd', 'Newport Creek Dr', 'W M 14', 'Cooley St', 'Sunset Rd', 'Hubbard St']
#
# RxDevice=31 FileId=952148 TxDevice=31 went through these roads:
# ['Hubbard St', 'S Huron Pkwy', 'Glazier Way', 'Fuller Rd', 'N Campus Blvd', 'Maiden Ln', 'Fuller St', 'Glen Ave', 'Glen Ct', 'Catherine St', 'E Ann St', 'E Huron St', 'N Ingalls St', 'W Huron St', 'S 1st St', 'W Liberty St', 'W William St', 'S Ashley St']
#
# RxDevice=31 FileId=952150 TxDevice=31 went through these roads:
# ['S Main St', 'W Jefferson St', 'W Madison St', 'W Mosley St', 'Koch Ave', 'Pauline Blvd', 'Potter Ave', 'Berkley Ave', 'Snyder Ave', 'W Stadium Blvd', 'Kingsbrook Ave', 'W Oakbrook Dr', 'Briarwood Cir', 'W Eisenhower Pkwy']
#
# RxDevice=31 FileId=952151 TxDevice=31 went through these roads:
# ['Plaza Rd', 'E Eisenhower Pkwy', 'Eisenhower Pkwy', 'Eisenhower Pl', 'Alpine Dr', 'S Service Dr', 'Packard St', 'Saint Aubin Ave', 'Rosedale St', 'Creek Dr', 'Carpenter Rd', 'Carpenter Pl']
#
# RxDevice=31 FileId=952152 TxDevice=31 went through these roads:
# [None, 'Carpenter Rd', 'Coachville Cir', 'Packard St', 'Hogback Rd', 'E Huron River Dr', 'Woodland Rd', 'S Huron Pkwy', 'Huron River/Huron Pkwy Ramp', 'Huron River Dr', 'Fuller Rd', 'Heritage']
#
# RxDevice=31 FileId=952154 TxDevice=31 went through these roads:
# [None, 'S Huron Pkwy', 'Heritage', 'Lake Haven Dr', 'Glazier Way', 'Green Rd', 'Vintage Valley Rd', 'Frederick Dr']
#
# RxDevice=31 FileId=952155 TxDevice=31 went through these roads:
# ['Hubbard St', 'S Huron Pkwy', 'Glazier Way', None]
#
# RxDevice=31 FileId=952156 TxDevice=31 went through these roads:
# [None, 'S Huron Pkwy', 'Heritage', 'Lake Haven Dr', 'Glazier Way', 'Green Rd', 'Vintage Valley Rd', 'Frederick Dr']
#
# RxDevice=32 FileId=26307 TxDevice=32 went through these roads:
# ['Roosevelt St', 'Harding St', 'Cherry Hill Rd', 'Ridge Rd', 'Uptown Ave', 'Roanoke Ave', 'Dominion Blvd', 'Ford Rd', 'Frains Lake Rd', 'W M 153', 'E M 153', 'Plymouth Rd', 'Birch Run Dr', 'Allendale Dr', 'Brittanie Dr', 'Vorhies Rd', 'Tanglewood Dr', 'Church Rd', 'N Dixboro Rd', 'Whitehall Dr', 'Earhart Rd', 'N Earhart Pl', 'N US 23', 'S US 23', None, 'Green Rd', 'Baxter Rd', 'Hubbard St', 'Hayward St']
#
# RxDevice=32 FileId=26308 TxDevice=32 went through these roads:
# ['Beal Ave', 'Hayward St', 'Hubbard St', 'S Huron Pkwy', None, 'Baxter Rd', 'Nixon Rd']
#
# RxDevice=32 FileId=26309 TxDevice=32 went through these roads:
# ['Nixon Rd', 'S Huron Pkwy', 'Plymouth Rd', 'Baxter Rd', None, 'Hubbard St', 'Hayward St', 'Beal Ave']
#
# RxDevice=32 FileId=26310 TxDevice=32 went through these roads:
# ['Beal Ave', 'Hayward St', 'Hubbard St', 'S Huron Pkwy', None, 'Baxter Rd']
#
# RxDevice=32 FileId=26316 TxDevice=32 went through these roads:
# ['Baxter Rd', 'S Huron Pkwy', 'Plymouth Rd', 'Green Rd', 'N US 23', 'Church Rd', 'Ford Rd', 'E M 153', 'Ridge Rd', 'Dominion Blvd', None, 'Roanoke Ave', 'Uptown Ave', 'Cherry Hill Rd', 'Harding St', 'Roosevelt St']
#
# RxDevice=32 FileId=26317 TxDevice=32 went through these roads:
# ['Roosevelt St', 'Harding St', 'Cherry Hill Rd', 'Beck Rd', 'Ford Rd', 'Lyndon Ave', 'Gyde Rd', 'Ann Arbor Rd', 'Haggerty Rd', 'Edward N Hines Dr', 'Middle Rouge Parkway Trl', 'Risman Dr', 'Plymouth Rd', 'Schoolcraft Rd', 'E M 14', 'W M 14', None]
#
# RxDevice=33 FileId=27036 TxDevice=33 went through these roads:
# ['Georgetown Blvd', 'Bluett Rd', 'Bunker Hill Rd', None]
#
# RxDevice=33 FileId=27037 TxDevice=33 went through these roads:
# [None, 'Bluett Rd', 'Georgetown Blvd', 'Yorktown Dr', 'Ardenne Dr']
#
# RxDevice=33 FileId=27039 TxDevice=33 went through these roads:
# ['Plymouth Rd', 'Lake Lila Dr', 'Upland Dr', 'Traver Rd', 'Moore St', 'Broadway St', 'Swift St', 'Depot St', 'Beakes St', 'E Summit St', 'Beakes Ct', 'N 4th Ave', 'W Kingsley St', 'N 1st St', 'Miller Rd', 'W Huron St', 'Jackson Ave', 'Grandview Dr', 'Worden Ave', 'Jackson Pl']
#
# RxDevice=33 FileId=27040 TxDevice=33 went through these roads:
# ['Jackson Ave', 'W Huron St', 'E Huron St', 'N Division St', 'Catherine St', 'E Kingsley St', 'Detroit St', 'Beakes St', 'Broadway St', 'Depot St', 'Wall St', 'Moore St', 'Plymouth Rd', 'Beal Ave']
#
# RxDevice=33 FileId=27041 TxDevice=33 went through these roads:
# ['Georgetown Blvd', 'Plymouth Rd', 'Green Rd', None, 'S US 23', 'Earhart Rd', 'Geddes Rd', 'E Huron River Dr', 'Washtenaw Ave', 'Carpenter Rd']
#
# RxDevice=33 FileId=27043 TxDevice=33 went through these roads:
# ['Washtenaw Ave', 'Hogback Rd', None, 'N US 23', 'E Huron River Dr', 'Geddes Rd', 'Plymouth Rd', 'S US 23', 'Green Rd', 'Commonwealth Blvd', 'Georgetown Blvd']
#
# RxDevice=33 FileId=27044 TxDevice=33 went through these roads:
# ['Plymouth Rd', 'Green Rd', None, 'S US 23', 'Earhart Rd', 'Geddes Rd', 'E Huron River Dr', 'Washtenaw Ave', 'Carpenter Rd']
#
# RxDevice=36 FileId=28756 TxDevice=36 went through these roads:
# ['Old US 12', 'E I 94', 'W I 94', None, 'Chisholm Trl', 'Queen Oaks Dr', 'Manchester Rd', 'Coliseum Dr']
#
# RxDevice=36 FileId=28758 TxDevice=36 went through these roads:
# ['Manchester Rd', 'Old US 12', 'Arthur St', 'Lane St', 'Wilkinson St', 'Queen Oaks Dr', None, 'W I 94', 'Kalmbach Rd', 'Cavanaugh Lake Rd', 'Glazier Rd']
#
# RxDevice=40 FileId=29814 TxDevice=40 went through these roads:
# ['N Territorial Rd', 'Beck Rd', 'Burning Tree Ln', None, 'E M 14', 'Sheldon Rd', 'Northville Rd', 'Robinwood Dr', 'Haggerty Rd', 'Schoolcraft Rd', 'S I 275', 'Plymouth Rd', 'Ann Arbor Trl', 'Ann Arbor Rd', 'Joy Rd', 'I 275 Crossover', 'Cherry Hill Rd', 'Palmer Rd', 'Michigan Ave', 'Geddes Rd', 'Michigan/Sheldon TURN', 'Michigan/Belleville TURN', 'E Michigan/Beck TURN', 'WB US-12/WB Michigan cutoff', 'W US 12', 'Ecorse Rd', 'Willow Run/W US 12', 'E Ecorse/W Ecorse TURN', 'W US 12/S Wiard Ramp', 'E US 12/S Wiard Ramp', 'Wiard Rd', 'Tyler Rd', 'McCartney Ave', 'Cedarcliff Dr', 'Coolidge Rd', 'W I 94', 'E I 94', 'William Ave', 'Lakeview Ave', 'Grove St', 'Bridge Rd']
#
# RxDevice=40 FileId=29815 TxDevice=40 went through these roads:
# ['Bridge Rd', 'Ambassador Dr', 'Grove St', 'Ide Ave', 'Rawsonville Rd', 'South Service Rd', 'E I 94', None, 'W I 94', 'Wiard Rd', 'McCartney Ave', 'S Huron St', 'W Michigan Ave', 'N US 23 CD', 'N US 23', 'S US 23', 'S US 23 CD', 'E Ellsworth Rd', 'Stone School Rd', 'Ann Arbor Saline Rd', 'Jackson Ave', 'Jackson Rd']
#
# RxDevice=40 FileId=29816 TxDevice=40 went through these roads:
# ['S Zeeb Rd', None, 'E I 94', 'E M 14', 'Wagner Rd', 'Jackson Ave', 'W Liberty Rd', 'Scio Church Rd', 'Ann Arbor Saline Rd', 'W I 94', 'Stone School Rd', 'Platt Rd', 'E Ellsworth Rd', 'E I 94 CD', 'S US 23', 'N US 23', 'N US 23 CD', 'Carpenter Rd', 'Huron St', 'James L Hart Pkwy', 'Joe Hall Dr', 'Brinker Dr', 'S Huron River Dr']
#
# RxDevice=40 FileId=29818 TxDevice=40 went through these roads:
# ['McCartney Ave', 'Tyler Rd', 'Tyler/N Wiard Ramp', 'Wiard Rd', 'S Wiard / N Wiard TURN', 'Airport/S Wiard Ramp', 'Airport/N Wiard Ramp', 'N Wiard/W US 12 Ramp', 'N Wiard/E US 12 Ramp', 'Ecorse Rd', 'E US 12/Willow Run', 'E US 12', 'Michigan Ave', 'Schooner Dr', 'E Michigan/Beck TURN', 'Beck Rd', 'Victorian Blvd', 'Victorian Sq W', 'Sherstone Dr', 'Shepherd Ln', 'River Woods Dr', 'Northgate Dr', 'Central Park Blvd', 'Glastonbury Dr', 'Glengarry Blvd', 'Cherry Hill Rd', 'Ford Rd', 'Waddington Rd', 'Lyndon Ave', 'Gyde Rd', 'Golfview Ln', 'N Territorial Rd', 'Burning Tree Ln', None, 'E M 14', 'Sheldon Rd', 'Middle Rouge Parkway Trl', 'Edward N Hines Dr', 'Haggerty Rd', 'N I 275 CD', 'W M 14', 'N I 275', 'W I 96', '6 Mile Rd', 'E I 96', 'Fox Dr']
#
# RxDevice=40 FileId=29820 TxDevice=40 went through these roads:
# [None, 'E I 96', 'S I 275', 'W M 14', 'E M 14', 'Schoolcraft Rd', 'Plymouth Rd', 'Ann Arbor Trl', 'Ann Arbor Rd', 'Joy Rd', 'I 275 Crossover', 'Ford Rd', 'Cherry Hill Rd', 'Palmer Rd', 'Michigan Ave', 'Haggerty Rd', 'Geddes Rd', 'Michigan/Sheldon TURN', 'Belleville Rd', 'Michigan/Belleville TURN', 'E Michigan/Beck TURN']
#
# RxDevice=40 FileId=29821 TxDevice=40 went through these roads:
# ['Michigan Ave', 'WB US-12/WB Michigan cutoff', 'W US 12', 'Ecorse Rd', 'W US 12/Willow Run', 'Willow Run/W US 12', None, 'E Ecorse/W Ecorse TURN', 'W US 12/S Wiard Ramp', 'N Wiard/W US 12 Ramp', 'E US 12/S Wiard Ramp', 'Wiard Rd', 'Tyler Rd', 'McCartney Ave', 'Cedarcliff Dr', 'Coolidge Rd', 'E I 94', 'William Ave', 'Lakeview Ave', 'Grove St', 'Bridge Rd', 'Textile Rd', 'Harbour Cove Ct']
#
# RxDevice=41 FileId=30300 TxDevice=41 went through these roads:
# ['Trillium Woods Dr', 'Earhart Rd', 'High Ridge', 'Old Earhart Rd', 'N US 23', 'Kipling Dr', 'Glazier Way', 'Scott Pl', 'S Huron Pkwy']
#
# RxDevice=41 FileId=30301 TxDevice=41 went through these roads:
# ['Glazier Way', 'S Huron Pkwy', 'Green Rd', 'Vintage Valley Rd']
#
# RxDevice=41 FileId=30302 TxDevice=41 went through these roads:
# ['Plymouth Rd', 'S US 23', 'N US 23', 'Earhart Rd', 'Trillium Woods Dr']
#
# RxDevice=42 FileId=30614 TxDevice=42 went through these roads:
# [None, 'Baxter Rd', 'S Huron Pkwy', 'Hubbard St', 'Glazier Way', 'Fuller Rd', 'Huron River Dr', 'Huron River/Huron Pkwy Ramp', 'Boulder Dr', 'Asher Rd', 'Washtenaw Ave', 'Pittsfield Blvd', 'Service Dr', 'Yost Blvd', 'Carpenter Rd', 'Sparrow Wood Dr', 'Packard St', 'Woodland Hills Dr']
#
# RxDevice=42 FileId=30616 TxDevice=42 went through these roads:
# ['Woodland Hills Dr', 'Packard St', 'Carpenter Rd', 'Washtenaw Ave', None, 'N US 23', 'E Huron River Dr', 'Geddes Rd']
#
# RxDevice=42 FileId=30618 TxDevice=42 went through these roads:
# ['N US 23', None, 'Plymouth Rd', 'S US 23', 'Green Rd', 'Commonwealth Blvd', 'Georgetown Blvd', 'S Huron Pkwy']
#
# RxDevice=43 FileId=31215 TxDevice=43 went through these roads:
# ['Green Rd', 'Plymouth Rd', 'S US 23', 'N US 23', None, 'E M 14', 'W M 14', 'N US 23 BR', 'Warren Rd', 'US 23 Crossover', '6 Mile Rd', '9 Mile Rd', 'Fieldcrest Dr', 'Lee Rd', 'E Grand River Ave', 'E I 96 CD', 'E I 96', 'Spencer Rd', 'Hyne Rd', 'Highland Rd']

# %% [markdown]
# ### Create a Leaflet map

# %%
trip_map = folium.Map([42.264768, -83.755503], zoom_start= 10)
colours = ['red','blue','green','orange','yellow','black','white','magenta','lightblue','lightgreen']
for route in list_trips:
    folium.PolyLine(route, color=random.choice(colours)).add_to(trip_map)

# %% [markdown]
# ### Display map

# %%
trip_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
